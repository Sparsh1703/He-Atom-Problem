# %%
import sympy as smp

r1, r2 = smp.symbols('r1 r2 ', real=True, positive=True)
theta = smp.symbols('theta')
theta1, phi1 = smp.symbols('theta_1 phi_1')
theta2, phi2 = smp.symbols('theta_2 phi_2')

x1 = smp.Function(r'x1')(r1, theta1, phi1)
x2 = smp.Function(r'x2')(r2, theta2, phi2)

y1 = smp.Function(r'x1')(r1, theta1, phi1)
y2 = smp.Function(r'x2')(r2, theta2, phi2)

z1 = smp.Function(r'x1')(r1, theta1)
z2 = smp.Function(r'x2')(r2, theta2)

Psi = smp.Function('Psi')(r1, theta1, phi1, r2, theta2, phi2)
V = smp.Function('V')(r1, theta1, phi1, r2, theta2, phi2)
absolute_diff = smp.sqrt(r1**2 + r2**2 - 2*r1*r2*smp.cos(theta))

V_eff = -2/r1 - 2/r2 + 1/(absolute_diff)
Laplacian = (1/r1**2) * smp.diff(r1**2 * smp.diff(Psi, r1), r1) + (1/r2**2) * smp.diff(r2**2 * smp.diff(Psi, r2), r2) + (1/(r1**2 * smp.sin(theta1))) * smp.diff(smp.sin(theta1) * smp.diff(Psi, theta1), theta1) + (1/(r2**2 * smp.sin(theta2))) * smp.diff(smp.sin(theta2) * smp.diff(Psi, theta2), theta2) + (1/(r1**2 * smp.sin(theta1)**2)) * smp.diff(smp.diff(Psi, phi1), phi1) + (1/(r2**2 * smp.sin(theta2)**2)) * smp.diff(smp.diff(Psi, phi2), phi2)

# %%
x1 = r1 * smp.sin(theta1) * smp.cos(phi1)
x2 = r2 * smp.sin(theta2) * smp.cos(phi2)

y1 = r1 * smp.sin(theta1) * smp.sin(phi1)
y2 = r2 * smp.sin(theta2) * smp.sin(phi2)

z1 = r1 * smp.cos(theta1)
z2 = r2 * smp.cos(theta2)

# %%
Phi_1 = smp.Function('\Phi_1')(r1,theta1, phi1, r2, theta2, phi2)
Phi_2 = smp.Function('\Phi_2')(r1,theta1, phi1, r2, theta2, phi2)
Phi_3 = smp.Function('\Phi_3')(r1,theta1, phi1, r2, theta2, phi2)
Phi_4 = smp.Function('\Phi_4')(r1,theta1, phi1, r2, theta2, phi2)
Phi_5 = smp.Function('\Phi_5')(r1,theta1, phi1, r2, theta2, phi2)
Phi_6 = smp.Function('\Phi_6')(r1,theta1, phi1, r2, theta2, phi2)
Phi_7 = smp.Function('\Phi_7')(r1,theta1, phi1, r2, theta2, phi2)

# %%
Phi_1 = smp.exp(-2 * (r1 + r2))
Phi_2 = smp.exp(-2 * (r1 + r2)) * (r1 + r2)
Phi_3 = smp.exp(-2 * (r1 + r2)) * (absolute_diff)
Phi_4 = smp.exp(-2 * (r1 + r2)) * r1 * r2
Phi_5 = smp.exp(-2 * (r1 + r2)) * (r1**2 + r2**2)
Phi_6 = smp.exp(-2 * (r1 + r2)) * (absolute_diff)**2
Phi_7 = smp.exp(-2 * (r1 + r2)) * (r1 + r2) * (absolute_diff)

# %%
r1_cartesian = smp.Matrix([x1, y1, z1])
r2_cartesian = smp.Matrix([x2, y2, z2])

# Compute the dot product
dot_product = r1_cartesian.dot(r2_cartesian)

magnitude_r1 = smp.sqrt(x1**2 + y1**2 + z1**2)
magnitude_r2 = smp.sqrt(x2**2 + y2**2 + z2**2)

# Compute cos(theta) and sin(theta)
cos_theta = dot_product / (magnitude_r1 * magnitude_r2)
sin_theta = smp.sqrt(1 - cos_theta**2)

# %%
Phi_1 = Phi_1.subs(smp.sin(theta), sin_theta).subs(smp.cos(theta), cos_theta)
Phi_2 = Phi_2.subs(smp.sin(theta), sin_theta).subs(smp.cos(theta), cos_theta)
Phi_3 = Phi_3.subs(smp.sin(theta), sin_theta).subs(smp.cos(theta), cos_theta)
Phi_4 = Phi_4.subs(smp.sin(theta), sin_theta).subs(smp.cos(theta), cos_theta)
Phi_5 = Phi_5.subs(smp.sin(theta), sin_theta).subs(smp.cos(theta), cos_theta)
Phi_6 = Phi_6.subs(smp.sin(theta), sin_theta).subs(smp.cos(theta), cos_theta)
Phi_7 = Phi_7.subs(smp.sin(theta), sin_theta).subs(smp.cos(theta), cos_theta)

# %%
V_eff = V_eff.subs(smp.sin(theta), sin_theta).subs(smp.cos(theta), cos_theta)
Hamiltonian = Laplacian + V * Psi

# %%
Hamiltonian
# Out:
# Psi(r1, theta_1, phi_1, r2, theta_2, phi_2)*V(r1, theta_1, phi_1, r2, theta_2, phi_2) + (r2**2*Derivative(Psi(r1, theta_1, phi_1, r2, theta_2, phi_2), (r2, 2)) + 2*r2*Derivative(Psi(r1, theta_1, phi_1, r2, theta_2, phi_2), r2))/r2**2 + (sin(theta_2)*Derivative(Psi(r1, theta_1, phi_1, r2, theta_2, phi_2), (theta_2, 2)) + cos(theta_2)*Derivative(Psi(r1, theta_1, phi_1, r2, theta_2, phi_2), theta_2))/(r2**2*sin(theta_2)) + Derivative(Psi(r1, theta_1, phi_1, r2, theta_2, phi_2), (phi_2, 2))/(r2**2*sin(theta_2)**2) + (r1**2*Derivative(Psi(r1, theta_1, phi_1, r2, theta_2, phi_2), (r1, 2)) + 2*r1*Derivative(Psi(r1, theta_1, phi_1, r2, theta_2, phi_2), r1))/r1**2 + (sin(theta_1)*Derivative(Psi(r1, theta_1, phi_1, r2, theta_2, phi_2), (theta_1, 2)) + cos(theta_1)*Derivative(Psi(r1, theta_1, phi_1, r2, theta_2, phi_2), theta_1))/(r1**2*sin(theta_1)) + Derivative(Psi(r1, theta_1, phi_1, r2, theta_2, phi_2), (phi_1, 2))/(r1**2*sin(theta_1)**2)

# %%
H_Phi_1 = Hamiltonian.subs({Psi: Phi_1, V:V_eff}).simplify()

# %%
H_Phi_2 = Hamiltonian.subs({Psi: Phi_2, V:V_eff}).simplify()

# %%
H_Phi_3 = Hamiltonian.subs({Psi: Phi_3, V:V_eff}).simplify()

# %%
H_Phi_4 = Hamiltonian.subs({Psi: Phi_4, V:V_eff}).simplify()

# %%
H_Phi_5 = Hamiltonian.subs({Psi: Phi_5, V:V_eff}).simplify()

# %%
H_Phi_6 = Hamiltonian.subs({Psi: Phi_6, V:V_eff}).simplify()

# %%
H_Phi_7 = Hamiltonian.subs({Psi: Phi_7, V:V_eff}).simplify()

# %%
f_11 = (Phi_1 * H_Phi_1) * r1**2 * r2**2
# f_11 = f_11.simplify()
# f_11

# %%
f_12 = (Phi_1 * H_Phi_2) * r1**2 * r2**2
# f_12 = f_12.simplify()
# f_12

# %%
f_13 = (Phi_1 * H_Phi_3) * r1**2 * r2**2
# f_13 = f_13.simplify()
# f_13

# %%
f_14 = (Phi_1 * H_Phi_4) * r1**2 * r2**2
# f_14 = f_14.simplify()
# f_14

# %%
f_15 = (Phi_1 * H_Phi_5) * r1**2 * r2**2
# f_15 = f_15.simplify()
# f_15

# %%
f_16 = (Phi_1 * H_Phi_6) * r1**2 * r2**2
# f_16 = f_16.simplify()
# f_16

# %%
f_17 = (Phi_1 * H_Phi_7) * r1**2 * r2**2
# f_17 = f_17.simplify()
# f_17

# %%
f_22 = (Phi_2 * H_Phi_2) * r1**2 * r2**2
# f_22 = f_22.simplify()
# f_22

# %%
f_23 = (Phi_2 * H_Phi_3) * r1**2 * r2**2
# f_23 = f_23.simplify()
# f_23

# %%
f_24 = (Phi_2 * H_Phi_4) * r1**2 * r2**2
# f_24 = f_24.simplify()
# f_24

# %%
f_25 = (Phi_2 * H_Phi_5) * r1**2 * r2**2
# f_25 = f_25.simplify()
# f_25

# %%
f_26 = (Phi_2 * H_Phi_6) * r1**2 * r2**2
# f_26 = f_26.simplify()
# f_26

# %%
f_27 = (Phi_2 * H_Phi_7) * r1**2 * r2**2
# f_27 = f_27.simplify()
# f_27

# %%
f_33 = (Phi_3 * H_Phi_3) * r1**2 * r2**2
# f_33 = f_33.simplify()
# f_33

# %%
f_34 = (Phi_3 * H_Phi_4) * r1**2 * r2**2
# f_34 = f_34.simplify()
# f_34

# %%
f_35 = (Phi_3 * H_Phi_5) * r1**2 * r2**2
# f_35 = f_35.simplify()
# f_35

# %%
f_36 = (Phi_3 * H_Phi_6) * r1**2 * r2**2
# f_36 = f_36.simplify()
# f_36

# %%
f_37 = (Phi_3 * H_Phi_7) * r1**2 * r2**2
# f_37 = f_37.simplify()
# f_37

# %%
f_44 = (Phi_4 * H_Phi_4) * r1**2 * r2**2
# f_44 = f_44.simplify()
# f_44

# %%
f_45 = (Phi_4 * H_Phi_5) * r1**2 * r2**2
# f_45 = f_45.simplify()
# f_45

# %%
f_46 = (Phi_4 * H_Phi_6) * r1**2 * r2**2
# f_46 = f_46.simplify()
# f_46

# %%
f_47 = (Phi_4 * H_Phi_7) * r1**2 * r2**2
# f_47 = f_47.simplify()
# f_47

# %%
f_55 = (Phi_5 * H_Phi_5) * r1**2 * r2**2
# f_55 = f_55.simplify()
# f_55

# %%
f_56 = (Phi_5 * H_Phi_6) * r1**2 * r2**2
# f_56 = f_56.simplify()
# f_56

# %%
f_57 = (Phi_5 * H_Phi_7) * r1**2 * r2**2
# f_57 = f_57.simplify()
# f_57

# %%
f_66 = (Phi_6 * H_Phi_6) * r1**2 * r2**2
# f_66 = f_66.simplify()
# f_66

# %%
f_67 = (Phi_6 * H_Phi_7) * r1**2 * r2**2
# f_67 = f_67.simplify()
# f_67

# %%
f_77 = (Phi_7 * H_Phi_7) * r1**2 * r2**2
# f_77 = f_77.simplify()
# f_77

# %%
P_1 = f_11 + f_22 + f_33 + f_44 + f_55 + f_66 + f_77
P_2 = f_11 + f_12 + f_13 + f_14 + f_15 + f_16 + f_17 + f_22 + f_23 + f_24 + f_25 + f_26 + f_27 + f_33 + f_34 + f_35 + f_36 + f_37 + f_44 + f_45 + f_46 + f_47 + f_55 + f_56 + f_57 + f_66 + f_67 + f_77

# %%
f_11_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_11)
f_12_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_12)
f_13_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_13)
f_14_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_14)
f_15_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_15)
f_16_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_16)
f_17_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_17)
f_22_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_22)
f_23_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_23)
f_24_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_24)
f_25_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_25)
f_26_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_26)
f_27_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_27)
f_33_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_33)
f_34_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_34)
f_35_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_35)
f_36_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_36)
f_37_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_37)
f_44_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_44)
f_45_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_45)
f_46_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_46)
f_47_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_47)
f_55_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_55)
f_56_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_56)
f_57_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_57)
f_66_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_66)
f_67_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_67)
f_77_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], f_77)

P_1_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], P_1)
P_2_f = smp.lambdify([r1, theta1, phi1, r2, theta2, phi2], P_2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

r1 = np.linspace(0, 5, 10)
r2 = np.linspace(0, 5, 10)

theta1 = np.linspace(0, np.pi, 10)
theta2 = np.linspace(0, np.pi, 10)

phi1 = np.linspace(0, 2*np.pi, 10)
phi2 = np.linspace(0, 2*np.pi, 10)

R1, Theta1, Phi1, R2, Theta2, Phi2 = np.meshgrid(r1, theta1, phi1, r2, theta2, phi2)

# %%
F_11_6d = f_11_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_12_6d = f_12_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_13_6d = f_13_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_14_6d = f_14_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_15_6d = f_15_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_16_6d = f_16_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_17_6d = f_17_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_22_6d = f_22_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_23_6d = f_23_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_24_6d = f_24_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_25_6d = f_25_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_26_6d = f_26_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_27_6d = f_27_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_33_6d = f_33_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_34_6d = f_34_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_35_6d = f_35_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_36_6d = f_36_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_37_6d = f_37_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_44_6d = f_44_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_45_6d = f_45_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_46_6d = f_46_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_47_6d = f_47_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_55_6d = f_55_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_56_6d = f_56_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_57_6d = f_57_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_66_6d = f_66_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_67_6d = f_67_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
F_77_6d = f_77_f(R1, Theta1, Phi1, R2, Theta2, Phi2)

P_1_6d = P_1_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
P_2_6d = P_2_f(R1, Theta1, Phi1, R2, Theta2, Phi2)
# Out:
# <lambdifygenerated-1>:2: RuntimeWarning: invalid value encountered in sqrt
#   return r1**2*r2**2*(8*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 6*exp(-2*r1 - 2*r2)/r2 - 6*exp(-2*r1 - 2*r2)/r1)*exp(-2*r1 - 2*r2)
# <lambdifygenerated-1>:2: RuntimeWarning: divide by zero encountered in divide
#   return r1**2*r2**2*(8*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 6*exp(-2*r1 - 2*r2)/r2 - 6*exp(-2*r1 - 2*r2)/r1)*exp(-2*r1 - 2*r2)
# <lambdifygenerated-1>:2: RuntimeWarning: invalid value encountered in subtract
#   return r1**2*r2**2*(8*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 6*exp(-2*r1 - 2*r2)/r2 - 6*exp(-2*r1 - 2*r2)/r1)*exp(-2*r1 - 2*r2)
# <lambdifygenerated-1>:2: RuntimeWarning: invalid value encountered in multiply
#   return r1**2*r2**2*(8*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 6*exp(-2*r1 - 2*r2)/r2 - 6*exp(-2*r1 - 2*r2)/r1)*exp(-2*r1 - 2*r2)
# <lambdifygenerated-2>:2: RuntimeWarning: invalid value encountered in sqrt
#   return (r1**3*r2**2/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**3*r2 + r1**2*r2**3/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 8*r1**2*r2**2*(r1 + r2 - 1)*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) - 4*r1**2*r2**2 + 2*r1**2*r2*(-2*(r1 + r2)*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) - 2*r1*r2**3 + 2*r1*r2**2*(-2*(r1 + r2)*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2))*exp(-4*r1 - 4*r2)
# <lambdifygenerated-2>:2: RuntimeWarning: divide by zero encountered in divide
#   return (r1**3*r2**2/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**3*r2 + r1**2*r2**3/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 8*r1**2*r2**2*(r1 + r2 - 1)*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) - 4*r1**2*r2**2 + 2*r1**2*r2*(-2*(r1 + r2)*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) - 2*r1*r2**3 + 2*r1*r2**2*(-2*(r1 + r2)*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2))*exp(-4*r1 - 4*r2)
# <lambdifygenerated-2>:2: RuntimeWarning: invalid value encountered in divide
#   return (r1**3*r2**2/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**3*r2 + r1**2*r2**3/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 8*r1**2*r2**2*(r1 + r2 - 1)*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) - 4*r1**2*r2**2 + 2*r1**2*r2*(-2*(r1 + r2)*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) - 2*r1*r2**3 + 2*r1*r2**2*(-2*(r1 + r2)*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2))*exp(-4*r1 - 4*r2)
# <lambdifygenerated-3>:2: RuntimeWarning: divide by zero encountered in divide
#   return r1**2*r2**2*(-r1*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_1)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_2)) + r1*(-r1*r2*(sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) - sin(theta_2)*cos(theta_1))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)) + (-((-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + (-((r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2) + 2*((-r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r1*cos(theta_1)*cos(theta_2) + r2)*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))/r2 - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2)/r2 + (-r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)/(r2**2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*tan(theta_2)) - r2*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_2)/(r1*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_1)) + r2*(-r1*r2*(sin(theta_1)*cos(theta_2) - sin(theta_2)*cos(theta_1)*cos(phi_1 - phi_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/(r1*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)) + 2*((r1 - r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))/r1 - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_ ...
# <lambdifygenerated-3>:2: RuntimeWarning: invalid value encountered in divide
#   return r1**2*r2**2*(-r1*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_1)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_2)) + r1*(-r1*r2*(sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) - sin(theta_2)*cos(theta_1))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)) + (-((-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + (-((r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2) + 2*((-r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r1*cos(theta_1)*cos(theta_2) + r2)*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))/r2 - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2)/r2 + (-r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)/(r2**2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*tan(theta_2)) - r2*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_2)/(r1*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_1)) + r2*(-r1*r2*(sin(theta_1)*cos(theta_2) - sin(theta_2)*cos(theta_1)*cos(phi_1 - phi_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/(r1*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)) + 2*((r1 - r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))/r1 - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_ ...
# <lambdifygenerated-3>:2: RuntimeWarning: invalid value encountered in sqrt
#   return r1**2*r2**2*(-r1*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_1)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_2)) + r1*(-r1*r2*(sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) - sin(theta_2)*cos(theta_1))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)) + (-((-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + (-((r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2) + 2*((-r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r1*cos(theta_1)*cos(theta_2) + r2)*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))/r2 - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2)/r2 + (-r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)/(r2**2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*tan(theta_2)) - r2*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_2)/(r1*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_1)) + r2*(-r1*r2*(sin(theta_1)*cos(theta_2) - sin(theta_2)*cos(theta_1)*cos(phi_1 - phi_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/(r1*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)) + 2*((r1 - r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))/r1 - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_ ...
# <lambdifygenerated-3>:2: RuntimeWarning: invalid value encountered in add
#   return r1**2*r2**2*(-r1*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_1)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_2)) + r1*(-r1*r2*(sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) - sin(theta_2)*cos(theta_1))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)) + (-((-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + (-((r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2) + 2*((-r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r1*cos(theta_1)*cos(theta_2) + r2)*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))/r2 - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2)/r2 + (-r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)/(r2**2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*tan(theta_2)) - r2*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_2)/(r1*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_1)) + r2*(-r1*r2*(sin(theta_1)*cos(theta_2) - sin(theta_2)*cos(theta_1)*cos(phi_1 - phi_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/(r1*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)) + 2*((r1 - r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))/r1 - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_ ...
# <lambdifygenerated-4>:2: RuntimeWarning: invalid value encountered in sqrt
#   return r1**2*r2**2*(r1*r2*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1*(r2 - 1)*exp(-2*r1 - 2*r2) - 2*r1*exp(-2*r1 - 2*r2) + 4*r2*(r1 - 1)*exp(-2*r1 - 2*r2) - 2*r2*exp(-2*r1 - 2*r2) + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r1*exp(-2*r1 - 2*r2))/r2 + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r2*exp(-2*r1 - 2*r2))/r1)*exp(-2*r1 - 2*r2)
# <lambdifygenerated-4>:2: RuntimeWarning: divide by zero encountered in divide
#   return r1**2*r2**2*(r1*r2*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1*(r2 - 1)*exp(-2*r1 - 2*r2) - 2*r1*exp(-2*r1 - 2*r2) + 4*r2*(r1 - 1)*exp(-2*r1 - 2*r2) - 2*r2*exp(-2*r1 - 2*r2) + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r1*exp(-2*r1 - 2*r2))/r2 + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r2*exp(-2*r1 - 2*r2))/r1)*exp(-2*r1 - 2*r2)
# <lambdifygenerated-4>:2: RuntimeWarning: invalid value encountered in divide
#   return r1**2*r2**2*(r1*r2*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1*(r2 - 1)*exp(-2*r1 - 2*r2) - 2*r1*exp(-2*r1 - 2*r2) + 4*r2*(r1 - 1)*exp(-2*r1 - 2*r2) - 2*r2*exp(-2*r1 - 2*r2) + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r1*exp(-2*r1 - 2*r2))/r2 + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r2*exp(-2*r1 - 2*r2))/r1)*exp(-2*r1 - 2*r2)
# <lambdifygenerated-4>:2: RuntimeWarning: invalid value encountered in multiply
#   return r1**2*r2**2*(r1*r2*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1*(r2 - 1)*exp(-2*r1 - 2*r2) - 2*r1*exp(-2*r1 - 2*r2) + 4*r2*(r1 - 1)*exp(-2*r1 - 2*r2) - 2*r2*exp(-2*r1 - 2*r2) + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r1*exp(-2*r1 - 2*r2))/r2 + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r2*exp(-2*r1 - 2*r2))/r1)*exp(-2*r1 - 2*r2)
# <lambdifygenerated-5>:2: RuntimeWarning: invalid value encountered in sqrt
#   return (r1**4*r2**2/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**4*r2 - 2*r1**3*r2**2 + r1**2*r2**4/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**2*r2**3 + 2*r1**2*r2**2*(-4*r1*exp(-2*r1 - 2*r2) + 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2**2*(-4*r2*exp(-2*r1 - 2*r2) + 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2*(2*r2*exp(-2*r1 - 2*r2) - 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) - 2*r1*r2**4 + 2*r1*r2**2*(2*r1*exp(-2*r1 - 2*r2) - 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2))*exp(-4*r1 - 4*r2)
# <lambdifygenerated-5>:2: RuntimeWarning: divide by zero encountered in divide
#   return (r1**4*r2**2/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**4*r2 - 2*r1**3*r2**2 + r1**2*r2**4/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**2*r2**3 + 2*r1**2*r2**2*(-4*r1*exp(-2*r1 - 2*r2) + 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2**2*(-4*r2*exp(-2*r1 - 2*r2) + 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2*(2*r2*exp(-2*r1 - 2*r2) - 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) - 2*r1*r2**4 + 2*r1*r2**2*(2*r1*exp(-2*r1 - 2*r2) - 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2))*exp(-4*r1 - 4*r2)
# <lambdifygenerated-5>:2: RuntimeWarning: invalid value encountered in divide
#   return (r1**4*r2**2/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**4*r2 - 2*r1**3*r2**2 + r1**2*r2**4/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**2*r2**3 + 2*r1**2*r2**2*(-4*r1*exp(-2*r1 - 2*r2) + 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2**2*(-4*r2*exp(-2*r1 - 2*r2) + 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2*(2*r2*exp(-2*r1 - 2*r2) - 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) - 2*r1*r2**4 + 2*r1*r2**2*(2*r1*exp(-2*r1 - 2*r2) - 2*(r1**2 + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2))*exp(-4*r1 - 4*r2)
# <lambdifygenerated-6>:2: RuntimeWarning: invalid value encountered in sqrt
#   return (r1**4*r2**2/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**4*r2 - 2*r1**3*r2**3*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**3*r2**3*cos(theta_1)*cos(theta_2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1**3*r2**2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + 4*r1**3*r2**2*cos(theta_1)*cos(theta_2) - 2*r1**3*r2**2 + 2*r1**3*r2*(sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1**3*r2*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_1)*cos(phi_1 - phi_2)/sin(theta_2) + r1**2*r2**4/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1**2*r2**3*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + 4*r1**2*r2**3*cos(theta_1)*cos(theta_2) - 2*r1**2*r2**3 + 2*r1**2*r2**2*(4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2) + 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2**2*(4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)*exp(-2*r1 - 2*r2) + 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2*((-2*r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*cos(theta_1)*cos(theta_2) + 2*r2)*exp(-2*r1 - 2*r2) - 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r1**2*(-2*r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + 2*r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/tan(theta_2) - 2*r1*r2**4 + 2*r1*r2**3*(sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1*r2**3*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_2)*cos(phi_1 - phi_2)/sin(theta_1) + 2*r1*r2**2*((2*r1 - 2*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2) - 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r2**2*(2*r1*r2*sin(theta_1)*cos(theta_2) - 2*r1*r2*sin(theta_2)*cos(theta_1)*cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/tan(theta_1))*exp(-4*r1 - 4*r2)
# <lambdifygenerated-6>:2: RuntimeWarning: divide by zero encountered in divide
#   return (r1**4*r2**2/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**4*r2 - 2*r1**3*r2**3*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**3*r2**3*cos(theta_1)*cos(theta_2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1**3*r2**2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + 4*r1**3*r2**2*cos(theta_1)*cos(theta_2) - 2*r1**3*r2**2 + 2*r1**3*r2*(sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1**3*r2*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_1)*cos(phi_1 - phi_2)/sin(theta_2) + r1**2*r2**4/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1**2*r2**3*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + 4*r1**2*r2**3*cos(theta_1)*cos(theta_2) - 2*r1**2*r2**3 + 2*r1**2*r2**2*(4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2) + 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2**2*(4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)*exp(-2*r1 - 2*r2) + 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2*((-2*r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*cos(theta_1)*cos(theta_2) + 2*r2)*exp(-2*r1 - 2*r2) - 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r1**2*(-2*r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + 2*r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/tan(theta_2) - 2*r1*r2**4 + 2*r1*r2**3*(sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1*r2**3*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_2)*cos(phi_1 - phi_2)/sin(theta_1) + 2*r1*r2**2*((2*r1 - 2*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2) - 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r2**2*(2*r1*r2*sin(theta_1)*cos(theta_2) - 2*r1*r2*sin(theta_2)*cos(theta_1)*cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/tan(theta_1))*exp(-4*r1 - 4*r2)
# <lambdifygenerated-6>:2: RuntimeWarning: invalid value encountered in divide
#   return (r1**4*r2**2/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**4*r2 - 2*r1**3*r2**3*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**3*r2**3*cos(theta_1)*cos(theta_2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1**3*r2**2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + 4*r1**3*r2**2*cos(theta_1)*cos(theta_2) - 2*r1**3*r2**2 + 2*r1**3*r2*(sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1**3*r2*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_1)*cos(phi_1 - phi_2)/sin(theta_2) + r1**2*r2**4/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1**2*r2**3*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + 4*r1**2*r2**3*cos(theta_1)*cos(theta_2) - 2*r1**2*r2**3 + 2*r1**2*r2**2*(4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2) + 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2**2*(4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)*exp(-2*r1 - 2*r2) + 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2*((-2*r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*cos(theta_1)*cos(theta_2) + 2*r2)*exp(-2*r1 - 2*r2) - 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r1**2*(-2*r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + 2*r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/tan(theta_2) - 2*r1*r2**4 + 2*r1*r2**3*(sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1*r2**3*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_2)*cos(phi_1 - phi_2)/sin(theta_1) + 2*r1*r2**2*((2*r1 - 2*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2) - 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r2**2*(2*r1*r2*sin(theta_1)*cos(theta_2) - 2*r1*r2*sin(theta_2)*cos(theta_1)*cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/tan(theta_1))*exp(-4*r1 - 4*r2)
# <lambdifygenerated-6>:2: RuntimeWarning: invalid value encountered in subtract
#   return (r1**4*r2**2/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**4*r2 - 2*r1**3*r2**3*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**3*r2**3*cos(theta_1)*cos(theta_2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1**3*r2**2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + 4*r1**3*r2**2*cos(theta_1)*cos(theta_2) - 2*r1**3*r2**2 + 2*r1**3*r2*(sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1**3*r2*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_1)*cos(phi_1 - phi_2)/sin(theta_2) + r1**2*r2**4/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1**2*r2**3*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + 4*r1**2*r2**3*cos(theta_1)*cos(theta_2) - 2*r1**2*r2**3 + 2*r1**2*r2**2*(4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2) + 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2**2*(4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)*exp(-2*r1 - 2*r2) + 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2*((-2*r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*cos(theta_1)*cos(theta_2) + 2*r2)*exp(-2*r1 - 2*r2) - 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r1**2*(-2*r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + 2*r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/tan(theta_2) - 2*r1*r2**4 + 2*r1*r2**3*(sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1*r2**3*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_2)*cos(phi_1 - phi_2)/sin(theta_1) + 2*r1*r2**2*((2*r1 - 2*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2) - 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r2**2*(2*r1*r2*sin(theta_1)*cos(theta_2) - 2*r1*r2*sin(theta_2)*cos(theta_1)*cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/tan(theta_1))*exp(-4*r1 - 4*r2)
# <lambdifygenerated-6>:2: RuntimeWarning: invalid value encountered in add
#   return (r1**4*r2**2/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**4*r2 - 2*r1**3*r2**3*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**3*r2**3*cos(theta_1)*cos(theta_2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1**3*r2**2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + 4*r1**3*r2**2*cos(theta_1)*cos(theta_2) - 2*r1**3*r2**2 + 2*r1**3*r2*(sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1**3*r2*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_1)*cos(phi_1 - phi_2)/sin(theta_2) + r1**2*r2**4/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1**2*r2**3*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + 4*r1**2*r2**3*cos(theta_1)*cos(theta_2) - 2*r1**2*r2**3 + 2*r1**2*r2**2*(4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2) + 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2**2*(4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)*exp(-2*r1 - 2*r2) + 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + exp(-2*(r1 + r2)))*exp(2*r1 + 2*r2) + 2*r1**2*r2*((-2*r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*cos(theta_1)*cos(theta_2) + 2*r2)*exp(-2*r1 - 2*r2) - 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r1**2*(-2*r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + 2*r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/tan(theta_2) - 2*r1*r2**4 + 2*r1*r2**3*(sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1*r2**3*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_2)*cos(phi_1 - phi_2)/sin(theta_1) + 2*r1*r2**2*((2*r1 - 2*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r2*cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2) - 2*(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r2**2*(2*r1*r2*sin(theta_1)*cos(theta_2) - 2*r1*r2*sin(theta_2)*cos(theta_1)*cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/tan(theta_1))*exp(-4*r1 - 4*r2)
# <lambdifygenerated-7>:2: RuntimeWarning: divide by zero encountered in divide
#   return (r1**3*r2**2 - r1**3*r2*(r1 + r2)*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_1)/(sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_2)) + r1**3*r2*(r1 + r2)*(-r1*r2*(sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) - sin(theta_2)*cos(theta_1))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**3*r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + r1**2*r2**3 - 4*r1**2*r2**2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + r1**2*r2**2*(-(r1 + r2)*((-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1 + r2)*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1 + r2)*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + r1**2*r2**2*(-(r1 + r2)*((r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1 + r2)*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1 + r2)*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1**2*r2*((r1 + r2)*(-r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r1*cos(theta_1)*cos(theta_2) + r2)*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*(r1 + r2)*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r1**2*(r1 + r2)*(-r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/(sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*tan(theta_2)) - r1*r2**3*(r1 + r2)*(r1*r2*sin(theta_1)*s ...
# <lambdifygenerated-7>:2: RuntimeWarning: invalid value encountered in divide
#   return (r1**3*r2**2 - r1**3*r2*(r1 + r2)*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)*sin(theta_1)/(sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_2)) + r1**3*r2*(r1 + r2)*(-r1*r2*(sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) - sin(theta_2)*cos(theta_1))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*r1**3*r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + r1**2*r2**3 - 4*r1**2*r2**2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + r1**2*r2**2*(-(r1 + r2)*((-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1 + r2)*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1 + r2)*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + r1**2*r2**2*(-(r1 + r2)*((r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1 + r2)*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1 + r2)*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2) + 2*r1**2*r2*((r1 + r2)*(-r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r1*cos(theta_1)*cos(theta_2) + r2)*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*(r1 + r2)*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2) + sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))*exp(2*r1 + 2*r2) + r1**2*(r1 + r2)*(-r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)*exp(2*r1 + 2*r2)/(sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*tan(theta_2)) - r1*r2**3*(r1 + r2)*(r1*r2*sin(theta_1)*s ...
# <lambdifygenerated-7>:2: RuntimeWarning: invalid value encountered in sqrt
# ...
# <lambdifygenerated-30>:2: RuntimeWarning: invalid value encountered in multiply
#   return r1**3*r2**3*(r1*r2*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1*(r2 - 1)*exp(-2*r1 - 2*r2) - 2*r1*exp(-2*r1 - 2*r2) + 4*r2*(r1 - 1)*exp(-2*r1 - 2*r2) - 2*r2*exp(-2*r1 - 2*r2) + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r1*exp(-2*r1 - 2*r2))/r2 + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r2*exp(-2*r1 - 2*r2))/r1)*exp(-2*r1 - 2*r2) + r1**2*r2**2*(r1 + r2)*(r1*r2*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1*(r2 - 1)*exp(-2*r1 - 2*r2) - 2*r1*exp(-2*r1 - 2*r2) + 4*r2*(r1 - 1)*exp(-2*r1 - 2*r2) - 2*r2*exp(-2*r1 - 2*r2) + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r1*exp(-2*r1 - 2*r2))/r2 + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r2*exp(-2*r1 - 2*r2))/r1)*exp(-2*r1 - 2*r2) + r1**2*r2**2*(r1 + r2)*(-r1*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_1)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_2)) + r1*(-r1*r2*(sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) - sin(theta_2)*cos(theta_1))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)) + (-((-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + (-((r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2) + 2*((-r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r1*cos(theta_1)*cos(theta_2) + r2)*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))/r2 - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2)/r2 + (-r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)/(r2**2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*tan(theta_2)) - r2*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_2)/(r1*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2** ...
# <lambdifygenerated-30>:2: RuntimeWarning: invalid value encountered in add
#   return r1**3*r2**3*(r1*r2*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1*(r2 - 1)*exp(-2*r1 - 2*r2) - 2*r1*exp(-2*r1 - 2*r2) + 4*r2*(r1 - 1)*exp(-2*r1 - 2*r2) - 2*r2*exp(-2*r1 - 2*r2) + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r1*exp(-2*r1 - 2*r2))/r2 + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r2*exp(-2*r1 - 2*r2))/r1)*exp(-2*r1 - 2*r2) + r1**2*r2**2*(r1 + r2)*(r1*r2*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1*(r2 - 1)*exp(-2*r1 - 2*r2) - 2*r1*exp(-2*r1 - 2*r2) + 4*r2*(r1 - 1)*exp(-2*r1 - 2*r2) - 2*r2*exp(-2*r1 - 2*r2) + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r1*exp(-2*r1 - 2*r2))/r2 + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r2*exp(-2*r1 - 2*r2))/r1)*exp(-2*r1 - 2*r2) + r1**2*r2**2*(r1 + r2)*(-r1*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_1)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_2)) + r1*(-r1*r2*(sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) - sin(theta_2)*cos(theta_1))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)) + (-((-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + (-((r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2) + 2*((-r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r1*cos(theta_1)*cos(theta_2) + r2)*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))/r2 - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2)/r2 + (-r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)/(r2**2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*tan(theta_2)) - r2*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_2)/(r1*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2** ...
# <lambdifygenerated-30>:2: RuntimeWarning: invalid value encountered in subtract
#   return r1**3*r2**3*(r1*r2*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1*(r2 - 1)*exp(-2*r1 - 2*r2) - 2*r1*exp(-2*r1 - 2*r2) + 4*r2*(r1 - 1)*exp(-2*r1 - 2*r2) - 2*r2*exp(-2*r1 - 2*r2) + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r1*exp(-2*r1 - 2*r2))/r2 + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r2*exp(-2*r1 - 2*r2))/r1)*exp(-2*r1 - 2*r2) + r1**2*r2**2*(r1 + r2)*(r1*r2*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*r1*(r2 - 1)*exp(-2*r1 - 2*r2) - 2*r1*exp(-2*r1 - 2*r2) + 4*r2*(r1 - 1)*exp(-2*r1 - 2*r2) - 2*r2*exp(-2*r1 - 2*r2) + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r1*exp(-2*r1 - 2*r2))/r2 + 2*(-2*r1*r2*exp(-2*r1 - 2*r2) + r2*exp(-2*r1 - 2*r2))/r1)*exp(-2*r1 - 2*r2) + r1**2*r2**2*(r1 + r2)*(-r1*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_1)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*sin(theta_2)) + r1*(-r1*r2*(sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) - sin(theta_2)*cos(theta_1))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + cos(theta_1)*cos(theta_2))*exp(-2*r1 - 2*r2)/(r2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)) + (-((-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(-r1 + r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r2*cos(theta_1)*cos(theta_2))/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + (-((r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 1)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*(r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) + r1*cos(theta_1)*cos(theta_2) - r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) + 4*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2))*exp(-2*r1 - 2*r2) + exp(-2*r1 - 2*r2) + 2*((-r1*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - r1*cos(theta_1)*cos(theta_2) + r2)*exp(-2*r1 - 2*r2)/sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2))/r2 - 2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*exp(-2*r1 - 2*r2)/r2 + (-r1*r2*sin(theta_1)*cos(theta_2)*cos(phi_1 - phi_2) + r1*r2*sin(theta_2)*cos(theta_1))*exp(-2*r1 - 2*r2)/(r2**2*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2)*tan(theta_2)) - r2*(r1*r2*sin(theta_1)*sin(theta_2)*sin(phi_1 - phi_2)**2/(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2**2) - cos(phi_1 - phi_2))*exp(-2*r1 - 2*r2)*sin(theta_2)/(r1*sqrt(r1**2 - 2*r1*r2*sin(theta_1)*sin(theta_2)*cos(phi_1 - phi_2) - 2*r1*r2*cos(theta_1)*cos(theta_2) + r2** ...

# %%
P_1_6d.shape
# Out:
# (10, 10, 10, 10, 10, 10)

# %%
F11_over_P1 = F_11_6d/P_1_6d
F12_over_P1 = F_12_6d/P_1_6d
F13_over_P1 = F_13_6d/P_1_6d
F14_over_P1 = F_14_6d/P_1_6d
F15_over_P1 = F_15_6d/P_1_6d
F16_over_P1 = F_16_6d/P_1_6d
F17_over_P1 = F_17_6d/P_1_6d
F22_over_P1 = F_22_6d/P_1_6d
F23_over_P1 = F_23_6d/P_1_6d
F24_over_P1 = F_24_6d/P_1_6d
F25_over_P1 = F_25_6d/P_1_6d
F26_over_P1 = F_26_6d/P_1_6d
F27_over_P1 = F_27_6d/P_1_6d
F33_over_P1 = F_33_6d/P_1_6d
F34_over_P1 = F_34_6d/P_1_6d
F35_over_P1 = F_35_6d/P_1_6d
F36_over_P1 = F_36_6d/P_1_6d
F37_over_P1 = F_37_6d/P_1_6d
F44_over_P1 = F_44_6d/P_1_6d
F45_over_P1 = F_45_6d/P_1_6d
F46_over_P1 = F_46_6d/P_1_6d
F47_over_P1 = F_47_6d/P_1_6d
F55_over_P1 = F_55_6d/P_1_6d
F56_over_P1 = F_56_6d/P_1_6d
F57_over_P1 = F_57_6d/P_1_6d
F66_over_P1 = F_66_6d/P_1_6d
F67_over_P1 = F_67_6d/P_1_6d
F77_over_P1 = F_77_6d/P_1_6d

# %%
F11_over_P2 = F_11_6d/P_2_6d
F12_over_P2 = F_12_6d/P_2_6d
F13_over_P2 = F_13_6d/P_2_6d
F14_over_P2 = F_14_6d/P_2_6d
F15_over_P2 = F_15_6d/P_2_6d
F16_over_P2 = F_16_6d/P_2_6d
F17_over_P2 = F_17_6d/P_2_6d
F22_over_P2 = F_22_6d/P_2_6d
F23_over_P2 = F_23_6d/P_2_6d
F24_over_P2 = F_24_6d/P_2_6d
F25_over_P2 = F_25_6d/P_2_6d
F26_over_P2 = F_26_6d/P_2_6d
F27_over_P2 = F_27_6d/P_2_6d
F33_over_P2 = F_33_6d/P_2_6d
F34_over_P2 = F_34_6d/P_2_6d
F35_over_P2 = F_35_6d/P_2_6d
F36_over_P2 = F_36_6d/P_2_6d
F37_over_P2 = F_37_6d/P_2_6d
F44_over_P2 = F_44_6d/P_2_6d
F45_over_P2 = F_45_6d/P_2_6d
F46_over_P2 = F_46_6d/P_2_6d
F47_over_P2 = F_47_6d/P_2_6d
F55_over_P2 = F_55_6d/P_2_6d
F56_over_P2 = F_56_6d/P_2_6d
F57_over_P2 = F_57_6d/P_2_6d
F66_over_P2 = F_66_6d/P_2_6d
F67_over_P2 = F_67_6d/P_2_6d
F77_over_P2 = F_77_6d/P_2_6d

# %%
F11_over_P1 = F11_over_P1.reshape((1000000,))
F12_over_P1 = F12_over_P1.reshape((1000000,))
F13_over_P1 = F13_over_P1.reshape((1000000,))
F14_over_P1 = F14_over_P1.reshape((1000000,))
F15_over_P1 = F15_over_P1.reshape((1000000,))
F16_over_P1 = F16_over_P1.reshape((1000000,))
F17_over_P1 = F17_over_P1.reshape((1000000,))
F22_over_P1 = F22_over_P1.reshape((1000000,))
F23_over_P1 = F23_over_P1.reshape((1000000,))
F24_over_P1 = F24_over_P1.reshape((1000000,))
F25_over_P1 = F25_over_P1.reshape((1000000,))
F26_over_P1 = F26_over_P1.reshape((1000000,))
F27_over_P1 = F27_over_P1.reshape((1000000,))
F33_over_P1 = F33_over_P1.reshape((1000000,))
F34_over_P1 = F34_over_P1.reshape((1000000,))
F35_over_P1 = F35_over_P1.reshape((1000000,))
F36_over_P1 = F36_over_P1.reshape((1000000,))
F37_over_P1 = F37_over_P1.reshape((1000000,))
F44_over_P1 = F44_over_P1.reshape((1000000,))
F45_over_P1 = F45_over_P1.reshape((1000000,))
F46_over_P1 = F46_over_P1.reshape((1000000,))
F47_over_P1 = F47_over_P1.reshape((1000000,))
F55_over_P1 = F55_over_P1.reshape((1000000,))
F56_over_P1 = F56_over_P1.reshape((1000000,))
F57_over_P1 = F57_over_P1.reshape((1000000,))
F66_over_P1 = F66_over_P1.reshape((1000000,))
F67_over_P1 = F67_over_P1.reshape((1000000,))
F77_over_P1 = F77_over_P1.reshape((1000000,))

# %% [markdown]
# ## Monte Carlo Integration and Metropolis Algorithm

# %%
r1 = np.linspace(0, 5, 10)
r2 = np.linspace(0, 5, 10)

theta1 = np.linspace(0, np.pi, 10)
theta2 = np.linspace(0, np.pi, 10)

phi1 = np.linspace(0, 2*np.pi, 10)
phi2 = np.linspace(0, 2*np.pi, 10)

R1, Theta1, Phi1, R2, Theta2, Phi2 = np.meshgrid(r1, theta1, phi1, r2, theta2, phi2)

# %%
import pandas as pd

# Flatten the arrays
R1_flat = R1.flatten()
R2_flat = R2.flatten()
Theta1_flat = Theta1.flatten()
Theta2_flat = Theta2.flatten()
Phi1_flat = Phi1.flatten()
Phi2_flat = Phi2.flatten()
F11_flat = F_11_6d.flatten()
P1_flat = P_1_6d.flatten()

# Create the DataFrame
df = pd.DataFrame({'r1': R1_flat, 'theta1': Theta1_flat, 'phi1': Phi1_flat, 'r2': R2_flat, 'theta2': Theta2_flat, 'phi2': Phi2_flat, 'F11': F11_flat, 'P1': P1_flat})

# Display the DataFrame
df
# Out:
#          r1    theta1      phi1   r2    theta2      phi2  F11  P1
# 0       0.0  0.000000  0.000000  0.0  0.000000  0.000000  NaN NaN
# 1       0.0  0.000000  0.000000  0.0  0.000000  0.698132  NaN NaN
# 2       0.0  0.000000  0.000000  0.0  0.000000  1.396263  NaN NaN
# 3       0.0  0.000000  0.000000  0.0  0.000000  2.094395  NaN NaN
# 4       0.0  0.000000  0.000000  0.0  0.000000  2.792527  NaN NaN
# ...     ...       ...       ...  ...       ...       ...  ...  ..
# 999995  5.0  3.141593  6.283185  5.0  3.141593  3.490659  inf NaN
# 999996  5.0  3.141593  6.283185  5.0  3.141593  4.188790  inf NaN
# 999997  5.0  3.141593  6.283185  5.0  3.141593  4.886922  inf NaN
# 999998  5.0  3.141593  6.283185  5.0  3.141593  5.585054  inf NaN
# 999999  5.0  3.141593  6.283185  5.0  3.141593  6.283185  inf NaN
#
# [1000000 rows x 8 columns]

# %%
# Remove rows with nan or inf values in 'F11' or 'P1' columns
df_new = df.replace([np.inf, -np.inf], np.nan).dropna(subset=['F11', 'P1'])

# Display the cleaned DataFrame
df_new
# Out:
#               r1    theta1      phi1        r2    theta2      phi2  \
# 110111  0.555556  0.349066  0.000000  0.555556  0.349066  0.698132
# 110112  0.555556  0.349066  0.000000  0.555556  0.349066  1.396263
# 110113  0.555556  0.349066  0.000000  0.555556  0.349066  2.094395
# 110114  0.555556  0.349066  0.000000  0.555556  0.349066  2.792527
# 110115  0.555556  0.349066  0.000000  0.555556  0.349066  3.490659
# ...          ...       ...       ...       ...       ...       ...
# 999985  5.000000  3.141593  6.283185  5.000000  2.792527  3.490659
# 999986  5.000000  3.141593  6.283185  5.000000  2.792527  4.188790
# 999987  5.000000  3.141593  6.283185  5.000000  2.792527  4.886922
# 999988  5.000000  3.141593  6.283185  5.000000  2.792527  5.585054
# 999989  5.000000  3.141593  6.283185  5.000000  2.792527  6.283185
#
#                  F11            P1
# 110111 -6.607280e-03 -7.186096e-03
# 110112 -1.063459e-02 -1.940767e-02
# 110113 -1.181511e-02 -2.433515e-02
# 110114 -1.222510e-02 -2.667611e-02
# 110115 -1.222510e-02 -2.667611e-02
# ...              ...           ...
# 999985  1.639832e-14  4.624660e-11
# 999986  1.639832e-14  4.639112e-11
# 999987  1.639832e-14  4.636628e-11
# 999988  1.639832e-14  4.630798e-11
# 999989  1.639832e-14  4.653565e-11
#
# [654693 rows x 8 columns]

# %%
# Prepare the data for machine learning
X_features = df_new.iloc[:, :6].to_numpy()
yf_labels = df_new.iloc[:, 6:7].to_numpy()
yp_labels = df_new.iloc[:, 7:].to_numpy()

print(X_features.shape)
print(yf_labels.shape)
print(yp_labels.shape)
# Out:
# (654693, 6)
# (654693, 1)
# (654693, 1)

# %%
# Define the function
def f(X):
    r1, theta1, phi1, r2, theta2, phi2 = X

    result = f_11_f(r1, theta1, phi1, r2, theta2, phi2)
    # Check for NaN or inf values
    if np.isnan(result) or np.isinf(result):
        return -np.inf

    return result

def p(X):
    r1, theta1, phi1, r2, theta2, phi2 = X

    result_p = P_1_f(r1, theta1, phi1, r2, theta2, phi2)
    # Check for NaN or inf values
    if np.isnan(result_p) or np.isinf(result_p):
        return -np.inf

    return result_p

# Metropolis algorithm for multidimensional sampling
def metropolis_sampling(f, initial, num_samples, proposal_std):
    num_accept = 0
    current = initial
    current_value_f = f(current)
    current_value_p = p(current)
    samples = [current]

    for _ in range(num_samples):
        while True:
            # Propose a new candidate from a normal distribution
            candidate = np.random.normal(current, proposal_std)
            candidate_value_f = f(candidate)
            candidate_value_p = p(candidate)

            # Discard if candidate value is NaN or inf
            if candidate_value_f != -np.inf and candidate_value_p != -np.inf:
                break

        # Calculate acceptance probability
        acceptance_prob = min(1, candidate_value_f/current_value_f)

        # Accept or reject the candidate
        if np.random.uniform() < acceptance_prob:
            current = candidate
            current_value_f = candidate_value_f
            current_value_p = candidate_value_p
            num_accept +=1

        samples.append(current)

    return [np.array(samples), num_accept]

# Monte Carlo integration
def monte_carlo_integration(samples, f):
    values_f = np.array([f(sample) for sample in samples])
    # Filter out -inf values
    values_f = values_f[~np.isnan(values_f) & ~np.isinf(values_f)]

    values_p = np.array([p(sample) for sample in samples])
    # Filter out -inf values
    values_p = values_p[~np.isnan(values_p) & ~np.isinf(values_p)]

    values = values_f / values_p
    # Filter out nan and inf values
    values = values[~np.isnan(values) & ~np.isinf(values)]

    return np.mean(values)

# %%
X_features[233]
# Out:
# array([0.55555556, 0.34906585, 0.        , 1.66666667, 2.0943951 ,
#        3.4906585 ])

# %%
# Parameters
initial_point = X_features[233]
num_samples = 100000
proposal_std = 4

# Run Metropolis sampling
result = metropolis_sampling(f, initial_point, num_samples, proposal_std)

samples = result[0]
num_accept = result[1]

# Perform Monte Carlo integration
integral_estimate = monte_carlo_integration(samples, f)
print(f"Estimated integral: {integral_estimate}")
# Out:
# Estimated integral: 1.292450994610394e-05

# %%
print("Number of Samples Collected: %s"%len(samples))
print("Number of Samples Accepted: %s"%(num_accept))
print("Fraction Acceptances: %s"%(num_accept / num_samples))
# Out:
# Number of Samples Collected: 100001
# Number of Samples Accepted: 807
# Fraction Acceptances: 0.00807

# %%
samples = np.array(samples)
f_pred = f_11_f(samples[:, 0], samples[:, 1], samples[:, 2], samples[:, 3], samples[:, 4], samples[:, 5])
p_pred = P_1_f(samples[:, 0], samples[:, 1], samples[:, 2], samples[:, 3], samples[:, 4], samples[:, 5])

func = f_pred / p_pred
I = np.mean(func)
print(I)  ## This is the integration obtained through Monte Carlo method.
# Out:
# 1.292450994610394e-05
